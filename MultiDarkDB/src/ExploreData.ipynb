# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = loadtxt("../data/result_query_1.csv", delimiter=',', skiprows=44)
shape(data)
# Out:
# (10, 37)

# %%
scatter(data[:,4], data[:,5])

# %%
scatter(log10(data[:,11]), data[:,12])

# %%
data = loadtxt("../data/result_query_2.csv", delimiter=',', skiprows=18)

# %%
scatter(data[:,2], data[:,3], s=data[:,7]/1.0E12)

# %%
data = loadtxt("../data/result_query_3.csv", delimiter=',', skiprows=53)

# %%
scatter(data[:,4], data[:,5], s=data[:,12]*200)

# %%
data = loadtxt("../data/result_query_4.csv", delimiter=',', skiprows=32)

# %%
scatter(data[:,2], data[:,3], s=0.01)
